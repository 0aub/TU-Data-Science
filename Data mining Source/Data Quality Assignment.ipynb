# %%
import numpy as np
import pandas as pd

NewCustomerList = pd.read_excel(r'C:\Users\ayyub\Documents\1Python Scripts\Data\KPMG_VI_New_raw_data_update_final.xlsx'
                    , sheet_name='NewCustomerList', skiprows= [0])
CustomerDemographic = pd.read_excel(r'C:\Users\ayyub\Documents\1Python Scripts\Data\KPMG_VI_New_raw_data_update_final.xlsx'
                    , sheet_name='CustomerDemographic', skiprows= [0])
CustomerAddress = pd.read_excel(r'C:\Users\ayyub\Documents\1Python Scripts\Data\KPMG_VI_New_raw_data_update_final.xlsx'
                    , sheet_name='CustomerAddress', skiprows= [0])
Transactions = pd.read_excel(r'C:\Users\ayyub\Documents\1Python Scripts\Data\KPMG_VI_New_raw_data_update_final.xlsx'
                    , sheet_name='Transactions', skiprows= [0])

# %%
NewCustomerList
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
NewCustomerList['gender'].unique()
# Out:
# array(['Male', 'Female', 'U'], dtype=object)

# %%
# NAN Elements
last_name = NewCustomerList['last_name'].to_list()
nans = pd.isna(last_name)
for i in range(2):
    if i == True:
        index = np.where(nans == True)

print('\nlast_name',index[0] + 3)


DOB = NewCustomerList['DOB'].to_list()
nans = pd.isna(DOB)
for i in range(2):
    if i == True:
        index = np.where(nans == True)

print('\nDOB',index[0] + 3)


job_title = NewCustomerList['job_title'].to_list()
nans = pd.isna(job_title)
for i in range(2):
    if i == True:
        index = np.where(nans == True)

print('\njob_title',index[0] + 3)


job_industry_category = NewCustomerList['job_industry_category'].to_list()
nans = pd.isna(job_industry_category)
for i in range(2):
    if i == True:
        index = np.where(nans == True)

print('\njob_industry_category',index[0] + 3)
# Out:
# last_name [ 15  61  90 158 205 329 333 360 422 445 458 477 480 487 490 497 505 534
#  589 619 758 770 782 789 816 842 852 891 955]
#
# DOB [ 62 229 327 361 363 377 437 442 577 601 667 754 778 838 886 907 987]
#
# job_title [ 18  28  32  33  40  41  42  43  45  47  53  56  77  85  95  97  98 112
#  118 128 135 136 152 203 204 210 214 222 225 227 238 268 274 299 301 310
#  312 313 320 341 348 354 368 379 389 397 400 408 413 417 423 460 462 463
#  490 516 518 520 521 524 529 564 578 614 621 622 624 629 631 633 641 654
#  660 665 668 671 692 694 700 706 743 755 762 767 772 781 803 812 816 835
#  876 882 884 886 892 902 910 913 917 926 932 955 956 974 975 992]
#
# job_industry_category [ 25  26  36  39  46  47  50  60  61  72  76  88  90  93  96  97 111 115
#  124 125 127 134 135 138 161 162 166 167 173 179 185 190 199 200 201 203
#  207 208 210 219 225 235 237 240 242 247 260 261 268 278 283 286 290 293
#  295 306 309 317 323 330 333 334 340 342 353 357 371 373 378 390 392 393
# ...

# %%
CustomerDemographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 1954-01-20      Recruiting Manager
# ...

# %%
CustomerDemographic['gender'].unique()
# Out:
# array(['F', 'Male', 'Female', 'U', 'Femal', 'M'], dtype=object)

# %%
# NAN Elements
last_name = CustomerDemographic['last_name'].to_list()
nans = pd.isna(last_name)
for i in range(2):
    if i == True:
        index = np.where(nans == True)

print('\nlast_name',index[0] + 3)

DOB = CustomerDemographic['DOB'].to_list()
nans = pd.isna(DOB)
for i in range(2):
    if i == True:
        index = np.where(nans == True)

print('\nDOB',index[0] + 3)


job_title = CustomerDemographic['job_title'].to_list()
nans = pd.isna(job_title)
for i in range(2):
    if i == True:
        index = np.where(nans == True)

print('\njob_title',index[0] + 3)


job_industry_category = CustomerDemographic['job_industry_category'].to_list()
nans = pd.isna(job_industry_category)
for i in range(2):
    if i == True:
        index = np.where(nans == True)

print('\njob_industry_category',index[0] + 3)


default = CustomerDemographic['default'].to_list()
nans = pd.isna(default)
for i in range(2):
    if i == True:
        index = np.where(nans == True)

print('\ndefault',index[0] + 3)


tenure = CustomerDemographic['tenure'].to_list()
nans = pd.isna(tenure)
for i in range(2):
    if i == True:
        index = np.where(nans == True)

print('\ntenure',index[0] + 3)
# Out:
# last_name [   6   69  108  141  199  213  252  253  259  277  358  462  477  496
#   516  528  659  662  678  686  692  705  746  782  792  859  862  918
#   929  940 1063 1092 1131 1204 1225 1255 1268 1303 1322 1353 1378 1455
#  1457 1471 1514 1586 1613 1653 1693 1714 1729 1748 1758 1860 1891 1907
#  1937 1969 2063 2075 2081 2103 2139 2155 2191 2313 2357 2400 2409 2410
#  2463 2475 2517 2542 2582 2586 2617 2632 2718 2837 2896 2909 2914 2920
#  2921 2945 2947 2991 3040 3054 3055 3097 3139 3173 3175 3182 3190 3202
#  3261 3321 3323 3326 3327 3349 3366 3387 3399 3403 3445 3447 3449 3482
#  3557 3599 3626 3637 3653 3720 3758 3819 3887 3918 3929 3964 4001]
#
# DOB [ 146  170  269  292  453  455  456  482  515  528  550  584  601  682
#   687  801  841  885  894  952  977  985  998 1040 1046 1084 1176 1212
#  1246 1353 1479 1511 1585 1630 1685 1742 1775 1782 1808 1920 1940 1992
#  2002 2023 2071 2167 2207 2254 2297 2337 2343 2416 2428 2471 2542 2644
# ...

# %%
CustomerAddress.describe()
# Out:
#        customer_id     postcode  property_valuation
# count  3999.000000  3999.000000         3999.000000
# mean   2003.987997  2985.755939            7.514379
# std    1154.576912   844.878364            2.824663
# min       1.000000  2000.000000            1.000000
# 25%    1004.500000  2200.000000            6.000000
# 50%    2004.000000  2768.000000            8.000000
# 75%    3003.500000  3750.000000           10.000000
# max    4003.000000  4883.000000           12.000000

# %%
Transactions.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost  product_first_sold_date
# count   19803.000000             19803.000000
# mean      556.046951             38199.776549
# std       405.955660              2875.201110
# min         7.210000             33259.000000
# ...

# %%
# NAN Elements
online_order = Transactions['online_order'].to_list()
nans1 = pd.isna(online_order)
for i in range(2):
    if i == True:
        index1 = np.where(nans1 == True)

print('online_order',index1[0] + 3)


standard_cost = Transactions['standard_cost'].to_list()
nans2 = pd.isna(standard_cost)
for i in range(2):
    if i == True:
        index2 = np.where(nans2 == True)

print('\nstandard_cost',index2[0] + 3)


product_first_sold_date = Transactions['product_first_sold_date'].to_list()
nans3 = pd.isna(product_first_sold_date)
for i in range(2):
    if i == True:
        index3 = np.where(nans3 == True)

print('\nproduct_first_sold_date',index3[0] + 3)


brand = Transactions['brand'].to_list()
nans1 = pd.isna(brand)
for i in range(2):
    if i == True:
        index1 = np.where(nans1 == True)
        
print('\nbrand',index1[0] + 3)


product_line = Transactions['product_line'].to_list()
nans2 = pd.isna(product_line)
for i in range(2):
    if i == True:
        index2 = np.where(nans2 == True)
        
print('\nproduct_line',index2[0] + 3)


product_class = Transactions['product_class'].to_list()
nans3 = pd.isna(product_class)
for i in range(2):
    if i == True:
        index3 = np.where(nans3 == True)
        
print('\nproduct_class',index3[0] + 3)


product_size = Transactions['product_size'].to_list()
nans4 = pd.isna(product_size)
for i in range(2):
    if i == True:
        index4 = np.where(nans4 == True)
        
print('\nproduct_size',index4[0] + 3)


standard_cost = Transactions['standard_cost'].to_list()
nans5 = pd.isna(standard_cost)
for i in range(2):
    if i == True:
        index5 = np.where(nans5 == True)
        
print('\nstandard_cost',index5[0] + 3)
# Out:
# online_order [  100   169   172   253   303   339   345   401   479   532   561   579
#    763   772   846   917   920  1063  1074  1162  1195  1203  1357  1364
#   1374  1384  1526  1555  1558  1624  1820  1890  1924  1940  1983  1990
#   2098  2216  2286  2392  2617  2620  2635  2649  2650  2775  2844  3028
#   3035  3137  3203  3456  3535  3556  3815  3907  3932  3957  3960  4046
#   4049  4053  4073  4164  4270  4346  4350  4387  4480  4656  4683  4756
#   4805  4824  4834  4869  4891  5024  5031  5064  5356  5418  5436  5457
#   5463  5478  5564  5577  5645  5675  5720  5745  5758  5804  5837  5890
#   5895  5966  5980  6040  6114  6150  6252  6358  6380  6402  6417  6469
#   6473  6477  6522  6575  6630  6689  6746  6787  6855  6898  7082  7259
#   7270  7325  7327  7381  7432  7462  7531  7678  7729  7779  7836  7957
#   7976  8000  8030  8031  8039  8043  8055  8076  8089  8118  8163  8167
#   8408  8455  8628  8696  8812  8868  8936  8952  9059  9182  9303  9347
# ...
